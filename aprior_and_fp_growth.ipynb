# %% [markdown]
# # **Mounting Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Preprocessing for ARM**

# %%
import pandas as pd
import numpy as np

# Load Excel files
player_data = pd.read_excel("/content/drive/MyDrive/soccer_dataset/Player_Atrributes.xlsx", engine='openpyxl')
team_data = pd.read_excel("/content/drive/MyDrive/soccer_dataset/Team_Atrributes.xlsx", engine='openpyxl')

# Data Cleaning: Remove irrelevant columns
player_data.drop(columns=['player_fifa_api_id', 'player_api_id'], inplace=True, errors='ignore')
team_data.drop(columns=['team_fifa_api_id', 'team_api_id'], inplace=True, errors='ignore')

# Handle missing values
player_data.fillna(player_data.mean(numeric_only=True), inplace=True)
team_data.fillna(team_data.mean(numeric_only=True), inplace=True)
player_data.dropna(inplace=True)
team_data.dropna(inplace=True)

# Standardize date formats
player_data['date'] = pd.to_datetime(player_data['date'], errors='coerce')
team_data['date'] = pd.to_datetime(team_data['date'], errors='coerce')

# Filter Key Metrics
player_filtered = player_data[['date', 'overall_rating', 'potential', 'crossing',
                               'preferred_foot', 'attacking_work_rate', 'defensive_work_rate']]
team_filtered = team_data[['date', 'buildUpPlaySpeed', 'buildUpPlayDribbling',
                           'buildUpPlayPassing', 'chanceCreationPassing']]

# Create Summaries
player_summary = player_filtered.pivot_table(index='preferred_foot',
                                             values='overall_rating',
                                             aggfunc='mean').reset_index()

team_summary = team_filtered.pivot_table(index='date',
                                         values=['buildUpPlaySpeed', 'buildUpPlayDribbling', 'buildUpPlayPassing'],
                                         aggfunc='mean').reset_index()

# Aggregate Data
player_filtered['rating_to_potential_ratio'] = player_filtered['overall_rating'] / player_filtered['potential']

# Sort data for visualization
player_filtered.sort_values('date', inplace=True)
team_filtered.sort_values('date', inplace=True)

# Save cleaned data to new files for visualization
player_filtered.to_csv("Cleaned_Player_Data.csv", index=False)
team_filtered.to_csv("Cleaned_Team_Data.csv", index=False)

print("Data preprocessing complete. Cleaned data saved to CSV files.")

# %%
import pandas as pd
import numpy as np

# Load Excel files
player_data = pd.read_excel("/content/drive/MyDrive/soccer_dataset/Player_Atrributes.xlsx", engine='openpyxl')
team_data = pd.read_excel("/content/drive/MyDrive/soccer_dataset/Team_Atrributes.xlsx", engine='openpyxl')


# Step 1: Data Cleaning
irrelevant_cols_player = ['player_fifa_api_id', 'player_api_id']
irrelevant_cols_team = ['team_fifa_api_id', 'team_api_id']
player_data.drop(columns=irrelevant_cols_player, inplace=True, errors='ignore')
team_data.drop(columns=irrelevant_cols_team, inplace=True, errors='ignore')

# Handle missing values
player_data.fillna(player_data.mean(numeric_only=True), inplace=True)
team_data.fillna(team_data.mean(numeric_only=True), inplace=True)
player_data.dropna(inplace=True)
team_data.dropna(inplace=True)

# Standardize date formats
player_data['date'] = pd.to_datetime(player_data['date'], errors='coerce')
team_data['date'] = pd.to_datetime(team_data['date'], errors='coerce')

# Step 2: Filter Key Metrics and create explicit copies
player_metrics = ['date', 'overall_rating', 'potential', 'crossing',
                  'preferred_foot', 'attacking_work_rate', 'defensive_work_rate']
team_metrics = ['date', 'buildUpPlaySpeed', 'buildUpPlayDribbling',
                'buildUpPlayPassing', 'chanceCreationPassing']

player_filtered = player_data[player_metrics].copy()
team_filtered = team_data[team_metrics].copy()

# Step 3: Create Summaries
player_summary = player_filtered.pivot_table(
    index='preferred_foot',
    values='overall_rating',
    aggfunc='mean'
).reset_index()

team_summary = team_filtered.pivot_table(
    index='date',
    values=['buildUpPlaySpeed', 'buildUpPlayDribbling', 'buildUpPlayPassing'],
    aggfunc='mean'
).reset_index()

# Step 4: Aggregate Data
player_filtered['rating_to_potential_ratio'] = player_filtered['overall_rating'] / player_filtered['potential']

# Step 5: Format Data for Graphing
player_filtered = player_filtered.sort_values('date')
team_filtered = team_filtered.sort_values('date')

# Save cleaned data to new files for visualization
player_filtered.to_csv("Cleaned_Player_Data.csv", index=False)
team_filtered.to_csv("Cleaned_Team_Data.csv", index=False)

print("Data preprocessing complete. Cleaned data saved to CSV files.")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Data preprocessing complete. Cleaned data saved to CSV files.

# %% [markdown]
# # **Association Rule Mining for Soccer Team Attributes Using the Apriori Algorithm**

# %%
# Import necessary libraries
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Specify the file path
file_path = '/content/drive/MyDrive/soccer_dataset/preprocessed/Player_Atrributes final data.xlsx'

# Attempt to load data with flexible encoding and format handling
try:
    # Try loading as a CSV file with error handling for malformed lines
    players = pd.read_csv(file_path, encoding='ISO-8859-1', on_bad_lines='skip')
except Exception as e_csv:
    print(f"CSV load failed: {e_csv}. Trying to load as Excel.")
    try:
        players = pd.read_excel(file_path)
    except Exception as e_excel:
        print(f"Excel load failed: {e_excel}")
        raise ValueError("Failed to load the file. Please check the file format and path.")

# Display available columns to verify attributes
print("Available columns:", players.columns)

# Select relevant columns for analysis
attributes = ['overall_rating', 'potential', 'stamina', 'strength', 'agility']
available_attributes = [attr for attr in attributes if attr in players.columns]
df = players[available_attributes].dropna()

# Discretize continuous attributes into categorical bins
if 'overall_rating' in df.columns:
    df['overall_rating'] = pd.cut(df['overall_rating'], bins=[0, 60, 80, 100], labels=['Low', 'Medium', 'High'])
if 'potential' in df.columns:
    df['potential'] = pd.cut(df['potential'], bins=[0, 60, 80, 100], labels=['Low', 'Medium', 'High'])
if 'stamina' in df.columns:
    df['stamina'] = pd.cut(df['stamina'], bins=[0, 50, 70, 100], labels=['Low', 'Medium', 'High'])
if 'strength' in df.columns:
    df['strength'] = pd.cut(df['strength'], bins=[0, 50, 70, 100], labels=['Low', 'Medium', 'High'])
if 'agility' in df.columns:
    df['agility'] = pd.cut(df['agility'], bins=[0, 50, 70, 100], labels=['Low', 'Medium', 'High'])

# Convert categorical data to binary (one-hot encoding)
df_encoded = pd.get_dummies(df)

# Apply the Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(df_encoded, min_support=0.15, use_colnames=True)

# Generate association rules with a minimum confidence threshold
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

# Filter rules for effective player combinations based on high confidence and lift
effective_combinations = rules[(rules['confidence'] > 0.5) & (rules['lift'] > 1.0)]

# Display effective player attribute combinations
print("Effective Player Combinations:")
print(effective_combinations[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# CSV load failed: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
# . Trying to load as Excel.
# Available columns: Index(['id', 'player_fifa_api_id', 'player_api_id', 'date', 'overall_rating',
#        'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')
# Effective Player Combinations:
#                                           antecedents  \
# 0                             (overall_rating_Medium)
# 1                                  (potential_Medium)
# 3                                      (stamina_High)
# 5                                     (strength_High)
# 7                                      (agility_High)
# 8                                    (stamina_Medium)
# 10                                  (strength_Medium)
# 12                                   (agility_Medium)
# 14            (overall_rating_Medium, stamina_Medium)
# 17              (overall_rating_Medium, stamina_High)
# 18                   (potential_Medium, stamina_High)
# 19                                     (stamina_High)
# 20           (overall_rating_Medium, strength_Medium)
# 21                (potential_Medium, strength_Medium)
# 23             (overall_rating_Medium, strength_High)
# 24                  (potential_Medium, strength_High)
# 25                                    (strength_High)
# 26            (overall_rating_Medium, agility_Medium)
# 27                 (potential_Medium, agility_Medium)
# 28                                   (agility_Medium)
# 30                   (agility_High, potential_Medium)
# 33                    (stamina_Medium, strength_High)
# 35                    (stamina_High, strength_Medium)
# 36                      (strength_High, stamina_High)
# 37                     (agility_Medium, stamina_High)
# 38                       (agility_High, stamina_High)
# 40              (agility_High, overall_rating_Medium)
# 41                    (agility_High, strength_Medium)
# 42                    (agility_Medium, strength_High)
# 43                  (stamina_Medium, strength_Medium)
# 44                    (stamina_Medium, strength_High)
# 45                   (stamina_Medium, agility_Medium)
# 48                     (agility_Medium, stamina_High)
# 50                  (agility_Medium, strength_Medium)
# 51                   (agility_High, potential_Medium)
# 53                  (potential_Medium, strength_High)
# 54                    (agility_Medium, strength_High)
# 55  (overall_rating_Medium, stamina_Medium, streng...
# 58  (overall_rating_Medium, agility_Medium, stamin...
# 62    (potential_Medium, strength_High, stamina_High)
# 63                      (strength_High, stamina_High)
# 64  (overall_rating_Medium, agility_Medium, stamin...
# 65   (potential_Medium, agility_Medium, stamina_High)
# 66                     (agility_Medium, stamina_High)
# 68     (agility_High, stamina_High, potential_Medium)
# 70  (agility_High, strength_Medium, overall_rating...
# 71  (agility_High, potential_Medium, overall_ratin...
# 72  (agility_High, strength_Medium, potential_Medium)
# 73                    (agility_High, strength_Medium)
# 74  (overall_rating_Medium, strength_High, agility...
# 75  (overall_rating_Medium, strength_High, potenti...
# 76  (agility_Medium, strength_High, potential_Medium)
# 77                    (agility_Medium, strength_High)
#
#                                   consequents   support  confidence      lift
# 0                          (potential_Medium)  0.735294    0.873753  1.052279
# 1                     (overall_rating_Medium)  0.735294    0.885530  1.052279
# 3                     (overall_rating_Medium)  0.394275    0.900623  1.070214
# 5                     (overall_rating_Medium)  0.388459    0.894927  1.063446
# 7                     (overall_rating_Medium)  0.352249    0.881067  1.046976
# 8                          (potential_Medium)  0.400999    0.870111  1.047893
# 10                         (potential_Medium)  0.404918    0.848861  1.022300
# 12                         (potential_Medium)  0.415903    0.867412  1.044642
# 14                         (potential_Medium)  0.336312    0.900772  1.084818
# 17                         (potential_Medium)  0.330420    0.838044  1.009273
# 18                    (overall_rating_Medium)  0.330420    0.963712  1.145183
# 19  (overall_rating_Medium, potential_Medium)  0.330420    0.754761  1.026475
# 20                         (potential_Medium)  0.348395    0.884780  1.065559
# 21                    (overall_rating_Medium)  0.348395    0.860409  1.022427
# 23                         (potential_Medium)  0.337133    0.867871  1.045195
# 24                    (overall_rating_Medium)  0.337133    0.953512  1.133062
# 25  (overall_rating_Medium, potential_Medium)  0.337133    0.776681  1.056286
# 26                         (potential_Medium)  0.355966    0.908360  1.093956
# 27                    (overall_rating_Medium)  0.355966    0.855888  1.017056
# 28  (overall_rating_Medium, potential_Medium)  0.355966    0.742408  1.009674
# 30                    (overall_rating_Medium)  0.287757    0.936098  1.112369
# 33                    (overall_rating_Medium)  0.158399    0.893022  1.061182
# 35                    (overall_rating_Medium)  0.173053    0.906368  1.077041
# 36                    (overall_rating_Medium)  0.205503    0.900426  1.069980
# 37                    (overall_rating_Medium)  0.179777    0.910981  1.082523
# 38                    (overall_rating_Medium)  0.198730    0.891017  1.058799
# 40                          (strength_Medium)  0.215759    0.612520  1.284073
# 41                    (overall_rating_Medium)  0.215759    0.899644  1.069051
# 42                    (overall_rating_Medium)  0.231191    0.903614  1.073768
# 43                         (potential_Medium)  0.204639    0.876333  1.055385
# 44                         (potential_Medium)  0.155269    0.875372  1.054228
# 45                         (potential_Medium)  0.212900    0.890387  1.072311
# 48                         (potential_Medium)  0.167330    0.847908  1.021153
# 50                         (potential_Medium)  0.179804    0.904567  1.089388
# 51                          (strength_Medium)  0.192050    0.624755  1.309721
# 53                           (agility_Medium)  0.215428    0.609295  1.270751
# 54                         (potential_Medium)  0.215428    0.842005  1.014043
# 55                         (potential_Medium)  0.163433    0.903350  1.087923
# 58                         (potential_Medium)  0.170194    0.928561  1.118285
# 62                    (overall_rating_Medium)  0.169330    0.976889  1.160842
# 63  (overall_rating_Medium, potential_Medium)  0.169330    0.741932  1.009028
# 64                         (potential_Medium)  0.159242    0.885775  1.066757
# 65                    (overall_rating_Medium)  0.159242    0.951665  1.130867
# 66  (overall_rating_Medium, potential_Medium)  0.159242    0.806924  1.097417
# 68                    (overall_rating_Medium)  0.156486    0.977158  1.161161
# 70                         (potential_Medium)  0.181522    0.841315  1.013213
# 71                          (strength_Medium)  0.181522    0.630815  1.322427
# 72                    (overall_rating_Medium)  0.181522    0.945179  1.123160
# 73  (overall_rating_Medium, potential_Medium)  0.181522    0.756884  1.029362
# 74                         (potential_Medium)  0.205117    0.887220  1.068497
# 75                           (agility_Medium)  0.205117    0.608416  1.268919
# 76                    (overall_rating_Medium)  0.205117    0.952137  1.131428
# 77  (overall_rating_Medium, potential_Medium)  0.205117    0.801704  1.090317

# %% [markdown]
# # **Association Rule Mining for Soccer Player Attributes Using the FP Growth Algorithm**

# %%
import pandas as pd
from mlxtend.frequent_patterns import fpgrowth, association_rules

# Specify the file path
file_path = '/content/drive/MyDrive/soccer_dataset/preprocessed/Player_Atrributes final data.xlsx'

# Attempt to load data with flexible encoding and format handling
try:
    # Try loading as a CSV file with error handling for malformed lines
    players = pd.read_csv(file_path, encoding='ISO-8859-1', on_bad_lines='skip')
except Exception as e_csv:
    print(f"CSV load failed: {e_csv}. Trying to load as Excel.")
    try:
        players = pd.read_excel(file_path)
    except Exception as e_excel:
        print(f"Excel load failed: {e_excel}")
        raise ValueError("Failed to load the file. Please check the file format and path.")

# Display available columns to verify attributes
print("Available columns:", players.columns)

# Select only available columns relevant for the analysis
attributes = ['potential', 'stamina', 'strength', 'agility']
available_attributes = [attr for attr in attributes if attr in players.columns]
df = players[available_attributes].dropna()

# Discretize continuous attributes into categorical bins
if 'potential' in df.columns:
    df['potential'] = pd.cut(df['potential'], bins=[0, 60, 80, 100], labels=['Low', 'Medium', 'High'])
if 'stamina' in df.columns:
    df['stamina'] = pd.cut(df['stamina'], bins=[0, 50, 70, 100], labels=['Low', 'Medium', 'High'])
if 'strength' in df.columns:
    df['strength'] = pd.cut(df['strength'], bins=[0, 50, 70, 100], labels=['Low', 'Medium', 'High'])
if 'agility' in df.columns:
    df['agility'] = pd.cut(df['agility'], bins=[0, 50, 70, 100], labels=['Low', 'Medium', 'High'])

# Convert categorical data to binary (one-hot encoding)
df_encoded = pd.get_dummies(df)

# Apply FP-Growth with a lower min_support threshold
frequent_itemsets = fpgrowth(df_encoded, min_support=0.05, use_colnames=True)

# Generate association rules with lower confidence and lift thresholds
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

# Display all generated rules for inspection
print("All Generated Rules:")
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])

# Filter rules with relaxed thresholds for confidence and lift
effective_combinations = rules[(rules['confidence'] > 0.5) & (rules['lift'] > 1.0)]
print("\nEffective Player Combinations with Lower Thresholds:")
print(effective_combinations[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
# CSV load failed: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
# . Trying to load as Excel.
# Available columns: Index(['id', 'player_fifa_api_id', 'player_api_id', 'date', 'overall_rating',
#        'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')
# All Generated Rules:
#                                           antecedents         consequents  \
# 0                                    (agility_Medium)  (potential_Medium)
# 1                                    (stamina_Medium)  (potential_Medium)
# 2                    (stamina_Medium, agility_Medium)  (potential_Medium)
# 3                   (stamina_Medium, strength_Medium)  (potential_Medium)
# 4   (stamina_Medium, agility_Medium, strength_Medium)  (potential_Medium)
# 5                                     (strength_High)  (potential_Medium)
# 6                   (potential_Medium, strength_High)    (agility_Medium)
# 7                     (agility_Medium, strength_High)  (potential_Medium)
# 8                     (stamina_Medium, strength_High)  (potential_Medium)
# 9                     (stamina_Medium, strength_High)    (agility_Medium)
# 10  (potential_Medium, strength_High, stamina_Medium)    (agility_Medium)
# 11    (agility_Medium, strength_High, stamina_Medium)  (potential_Medium)
# 12                      (strength_High, stamina_High)  (potential_Medium)
# 13                     (agility_Medium, stamina_High)     (strength_High)
# 14    (potential_Medium, strength_High, stamina_High)    (agility_Medium)
# 15   (potential_Medium, agility_Medium, stamina_High)     (strength_High)
# 16      (agility_Medium, strength_High, stamina_High)  (potential_Medium)
# 17                                  (strength_Medium)  (potential_Medium)
# 18                  (agility_Medium, strength_Medium)  (potential_Medium)
# 19                                     (stamina_High)  (potential_Medium)
# 20                    (stamina_High, strength_Medium)  (potential_Medium)
# 21    (agility_Medium, stamina_High, strength_Medium)  (potential_Medium)
# 22                     (agility_Medium, stamina_High)  (potential_Medium)
# 23                                     (agility_High)  (potential_Medium)
# 24                   (agility_High, potential_Medium)   (strength_Medium)
# 25                    (agility_High, strength_Medium)  (potential_Medium)
# 26                       (agility_High, stamina_High)  (potential_Medium)
# 27                    (stamina_High, strength_Medium)      (agility_High)
# 28     (agility_High, stamina_High, potential_Medium)   (strength_Medium)
# 29      (agility_High, stamina_High, strength_Medium)  (potential_Medium)
# 30  (potential_Medium, stamina_High, strength_Medium)      (agility_High)
# 31                     (agility_High, stamina_Medium)  (potential_Medium)
# 32                     (agility_High, stamina_Medium)   (strength_Medium)
# 33   (agility_High, stamina_Medium, potential_Medium)   (strength_Medium)
# 34    (agility_High, stamina_Medium, strength_Medium)  (potential_Medium)
# 35                      (agility_High, strength_High)  (potential_Medium)
# 36                      (agility_High, strength_High)      (stamina_High)
# 37    (agility_High, strength_High, potential_Medium)      (stamina_High)
# 38        (agility_High, strength_High, stamina_High)  (potential_Medium)
# 39                                     (strength_Low)  (potential_Medium)
# 40                                     (strength_Low)      (agility_High)
# 41                                      (stamina_Low)  (potential_Medium)
# 42                                   (potential_High)      (stamina_High)
# 43                                   (potential_High)      (agility_High)
# 44                    (strength_High, potential_High)      (stamina_High)
# 45                     (agility_High, potential_High)      (stamina_High)
# 46                     (stamina_High, potential_High)      (agility_High)
# 47                                      (agility_Low)  (potential_Medium)
# 48                                      (agility_Low)     (strength_High)
# 49                    (agility_Low, potential_Medium)     (strength_High)
# 50                       (agility_Low, strength_High)  (potential_Medium)
# 51                      (agility_Low, stamina_Medium)  (potential_Medium)
#
#      support  confidence      lift
# 0   0.415903    0.867412  1.044642
# 1   0.400999    0.870111  1.047893
# 2   0.212900    0.890387  1.072311
# 3   0.204639    0.876333  1.055385
# 4   0.104007    0.906700  1.091957
# 5   0.353569    0.814548  0.980977
# 6   0.215428    0.609295  1.270751
# 7   0.215428    0.842005  1.014043
# 8   0.155269    0.875372  1.054228
# 9   0.110154    0.621028  1.295222
# 10  0.096778    0.623293  1.299948
# 11  0.096778    0.878565  1.058074
# 12  0.173336    0.759485  0.914663
# 13  0.134587    0.681990  1.571158
# 14  0.109116    0.629508  1.312908
# 15  0.109116    0.652103  1.502306
# 16  0.109116    0.810751  0.976404
# 17  0.404918    0.848861  1.022300
# 18  0.179804    0.904567  1.089388
# 19  0.342862    0.783181  0.943201
# 20  0.155464    0.814245  0.980612
# 21  0.056403    0.927429  1.116921
# 22  0.167330    0.847908  1.021153
# 23  0.307401    0.768891  0.925991
# 24  0.192050    0.624755  1.309721
# 25  0.192050    0.800784  0.964401
# 26  0.160144    0.718014  0.864719
# 27  0.128744    0.674296  1.686593
# 28  0.097832    0.610902  1.280680
# 29  0.097832    0.759900  0.915163
# 30  0.097832    0.629292  1.574025
# 31  0.136168    0.829262  0.998697
# 32  0.105344    0.641543  1.344915
# 33  0.089032    0.653840  1.370695
# 34  0.089032    0.845158  1.017841
# 35  0.070150    0.679764  0.818654
# 36  0.077716    0.753081  1.720225
# 37  0.050131    0.714629  1.632390
# 38  0.050131    0.645055  0.776853
# 39  0.071856    0.808118  0.973233
# 40  0.056773    0.638486  1.597023
# 41  0.086483    0.853228  1.027560
# 42  0.091957    0.621894  1.420561
# 43  0.088913    0.601309  1.504032
# 44  0.053637    0.704907  1.610184
# 45  0.061942    0.696662  1.591350
# 46  0.061942    0.673602  1.684857
# 47  0.107040    0.886633  1.067790
# 48  0.075020    0.621404  1.431581
# 49  0.067992    0.635200  1.463365
# 50  0.067992    0.906318  1.091497
# 51  0.051930    0.902428  1.086812
#
# Effective Player Combinations with Lower Thresholds:
#                                           antecedents         consequents  \
# 0                                    (agility_Medium)  (potential_Medium)
# 1                                    (stamina_Medium)  (potential_Medium)
# 2                    (stamina_Medium, agility_Medium)  (potential_Medium)
# 3                   (stamina_Medium, strength_Medium)  (potential_Medium)
# 4   (stamina_Medium, agility_Medium, strength_Medium)  (potential_Medium)
# 6                   (potential_Medium, strength_High)    (agility_Medium)
# 7                     (agility_Medium, strength_High)  (potential_Medium)
# 8                     (stamina_Medium, strength_High)  (potential_Medium)
# 9                     (stamina_Medium, strength_High)    (agility_Medium)
# 10  (potential_Medium, strength_High, stamina_Medium)    (agility_Medium)
# 11    (agility_Medium, strength_High, stamina_Medium)  (potential_Medium)
# 13                     (agility_Medium, stamina_High)     (strength_High)
# 14    (potential_Medium, strength_High, stamina_High)    (agility_Medium)
# 15   (potential_Medium, agility_Medium, stamina_High)     (strength_High)
# 17                                  (strength_Medium)  (potential_Medium)
# 18                  (agility_Medium, strength_Medium)  (potential_Medium)
# 21    (agility_Medium, stamina_High, strength_Medium)  (potential_Medium)
# 22                     (agility_Medium, stamina_High)  (potential_Medium)
# 24                   (agility_High, potential_Medium)   (strength_Medium)
# 27                    (stamina_High, strength_Medium)      (agility_High)
# 28     (agility_High, stamina_High, potential_Medium)   (strength_Medium)
# 30  (potential_Medium, stamina_High, strength_Medium)      (agility_High)
# 32                     (agility_High, stamina_Medium)   (strength_Medium)
# 33   (agility_High, stamina_Medium, potential_Medium)   (strength_Medium)
# 34    (agility_High, stamina_Medium, strength_Medium)  (potential_Medium)
# 36                      (agility_High, strength_High)      (stamina_High)
# 37    (agility_High, strength_High, potential_Medium)      (stamina_High)
# 40                                     (strength_Low)      (agility_High)
# 41                                      (stamina_Low)  (potential_Medium)
# 42                                   (potential_High)      (stamina_High)
# 43                                   (potential_High)      (agility_High)
# 44                    (strength_High, potential_High)      (stamina_High)
# 45                     (agility_High, potential_High)      (stamina_High)
# 46                     (stamina_High, potential_High)      (agility_High)
# 47                                      (agility_Low)  (potential_Medium)
# 48                                      (agility_Low)     (strength_High)
# 49                    (agility_Low, potential_Medium)     (strength_High)
# 50                       (agility_Low, strength_High)  (potential_Medium)
# 51                      (agility_Low, stamina_Medium)  (potential_Medium)
#
#      support  confidence      lift
# 0   0.415903    0.867412  1.044642
# 1   0.400999    0.870111  1.047893
# 2   0.212900    0.890387  1.072311
# 3   0.204639    0.876333  1.055385
# 4   0.104007    0.906700  1.091957
# 6   0.215428    0.609295  1.270751
# 7   0.215428    0.842005  1.014043
# 8   0.155269    0.875372  1.054228
# 9   0.110154    0.621028  1.295222
# 10  0.096778    0.623293  1.299948
# 11  0.096778    0.878565  1.058074
# 13  0.134587    0.681990  1.571158
# 14  0.109116    0.629508  1.312908
# 15  0.109116    0.652103  1.502306
# 17  0.404918    0.848861  1.022300
# 18  0.179804    0.904567  1.089388
# 21  0.056403    0.927429  1.116921
# 22  0.167330    0.847908  1.021153
# 24  0.192050    0.624755  1.309721
# 27  0.128744    0.674296  1.686593
# 28  0.097832    0.610902  1.280680
# 30  0.097832    0.629292  1.574025
# 32  0.105344    0.641543  1.344915
# 33  0.089032    0.653840  1.370695
# 34  0.089032    0.845158  1.017841
# 36  0.077716    0.753081  1.720225
# 37  0.050131    0.714629  1.632390
# 40  0.056773    0.638486  1.597023
# 41  0.086483    0.853228  1.027560
# 42  0.091957    0.621894  1.420561
# 43  0.088913    0.601309  1.504032
# 44  0.053637    0.704907  1.610184
# 45  0.061942    0.696662  1.591350
# 46  0.061942    0.673602  1.684857
# 47  0.107040    0.886633  1.067790
# 48  0.075020    0.621404  1.431581
# 49  0.067992    0.635200  1.463365
# 50  0.067992    0.906318  1.091497
# 51  0.051930    0.902428  1.086812
